# %%
import pandas as pd
import os
from typing import Tuple, List

# %%
goods_path = "data/goods/goods_data_100k.xlsx"
selected_posts_path = "data/posts/ajtkulov/selected/selected_posts_with_category.jsonl"
categories_mapping_path = "data/catgory_mapping_actual.json"
posts_categories_path = "data/posts/ajtkulov/meta/filtered_categories.csv"

# %%
posts = pd.read_csv(posts_categories_path, encoding='utf-8-sig')
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  1417 non-null   object
# dtypes: object(1)
# memory usage: 11.2+ KB

# %%
pd.read_excel(goods_path, usecols=["subj_root_name"])\
    .dropna().astype(str) \
    .drop_duplicates().to_csv(
    "subj_root_name_unique.csv",
    index=False,
    encoding="utf-8-sig"
)
# goods.head(10)
